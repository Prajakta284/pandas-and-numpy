# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams

# %%
# %matplotlib inline

params = { 
           'axes.labelsize' : 'x-large',
           'figure.figsize' : (8,6)
         }

rcParams.update(params)

# %%
df = pd.read_excel(r'C:\Users\A\Downloads\p\sheet_1.xlsx')
print(df)
# Out:
#         invno     docket  customerpo                       customername  \
# 0   J18003244  987001211  6566001207  FORCE MOTORS LTD. PITHAMPUR PLANT
# 1   J18003245  987001212  6566001207  FORCE MOTORS LTD. PITHAMPUR PLANT
# 2   J18003246  987001213  6566001209                                  0
# 3   J18003247  987001214  6566001201                                  0
# 4   J18003248  987001215  6566001201                                  0
# 5   J18003249  987001216  6566001201                                  0
# 6     4007756  987001217  6010011029                                  0
# 7     4007707  987001218  6467013672                                  0
# 8     4007708  987001219  6467013676                                  0
# 9     4007709  987001220  6467008932                                  0
# 10    4007710  987001221  6467014611                                  0
# 11    4007710  987001222  6467014611                                  0
# ...

# %%
df = df [['docket' , 'totalamount']]
print(df)
# Out:
#        docket  totalamount
# 0   987001211       746.00
# 1   987001212       186.49
# 2   987001213      3244.76
# 3   987001214       965.41
# 4   987001215       772.34
# 5   987001216      1930.84
# 6   987001217     44978.69
# 7   987001218      2678.79
# 8   987001219     20026.36
# 9   987001220      8301.32
# 10  987001221     15212.54
# 11  987001222     15212.54
# 12  987001223     19643.18
# 13  987001224         0.00
# 14  987001225         0.00
# 15  987001226         0.00
# 16  987001227     21046.28
# 17  987001228     21046.28
# 18  987001229   2269238.02
# 19  987001230     56486.22
# 20  987001231     99322.48
# 21  987001232     15589.92
# 22  987001233     11386.23
# 23  987001234      8774.78
# 24  987001235      8774.78
# 25  987001236     14747.64
# 26  987001237     46816.50
# 27  987001238     15605.50
# 28  987001239      6242.20
# 29  987001240      6028.62

# %%
x = df.docket

y = df.totalamount

# %%
plt.plot(x,y)
plt.xlabel('Docket',color = 'red')
plt.ylabel('Total Amount',color = 'green')
plt.show()

# %%
plt.scatter(x, y, alpha = 0.8)
